# %%
import pandas as pd
import numpy as np

# %%
tmp1 = pd.read_csv("data/01aJourneyDataExtract10Jan16-23Jan16.csv")
tmp1['EndStation Id'] = tmp1['EndStation Id'].fillna(9999).astype('int64')
tmp1['EndStation Name'] = tmp1['EndStation Name'].fillna('unknown')
tmp1['EndStation Name'] = tmp1['EndStation Name'].replace(" ,", ",")
tmp1['StartStation Id'] = tmp1['EndStation Id'].fillna(9999).astype('int64')
tmp1['StartStation Name'] = tmp1['StartStation Name'].fillna('unknown')
tmp1['StartStation Name'] = tmp1['StartStation Name'].replace(" ,", ",")
tmp1['Bike Id'] = tmp1['Bike Id'].fillna(0)
tmp1['End Date'] = pd.to_datetime(tmp1['End Date'])
tmp1['Start Date'] = pd.to_datetime(tmp1['Start Date'])
tmp1['Bike Model'] = 'CLASSIC'
tmp1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284587 entries, 0 to 284586
# Data columns (total 10 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Rental Id          284587 non-null  int64
#  1   Duration           284587 non-null  int64
#  2   Bike Id            284587 non-null  int64
#  3   End Date           284587 non-null  datetime64[ns]
#  4   EndStation Id      284587 non-null  int64
#  5   EndStation Name    284587 non-null  object
#  6   Start Date         284587 non-null  datetime64[ns]
#  7   StartStation Id    284587 non-null  int64
#  8   StartStation Name  284587 non-null  object
#  9   Bike Model         284587 non-null  object
# dtypes: datetime64[ns](2), int64(5), object(3)
# memory usage: 21.7+ MB

# %%
tmp1
# Out:
#         Rental Id  Duration  Bike Id            End Date  EndStation Id  \
# 0        50754225       240    11834 2016-10-01 00:04:00            383
# 1        50754226       300     9648 2016-10-01 00:05:00            719
# 2        50754227      1200    10689 2016-10-01 00:20:00            272
# 3        50754228       780     8593 2016-10-01 00:14:00            471
# 4        50754229       600     8619 2016-10-01 00:11:00            399
# ...           ...       ...      ...                 ...            ...
# 284582   51071167       480     5304 2016-01-23 17:10:00            200
# 284583   51071169        60    13298 2016-01-23 19:14:00            104
# 284584   51071170        60     7388 2016-01-23 21:01:00            104
# 284585   51109280       840    13350 2016-01-22 14:47:00            471
# 284586   51109295       900     7705 2016-01-23 14:50:00            471
#
#                             EndStation Name          Start Date  \
# ...

# %%
tmp1.to_parquet('01aJourneyDataExtract10Jan16-23Jan16.parquet', compression='gzip')

# %%
tmp2 = pd.read_csv("data/336JourneyDataExtract19Sep2022-25Sep2022.csv")
tmp2.drop(columns='Total duration', inplace=True)
tmp2.rename(columns={
    'Number': 'Rental Id',
    'Start date':'Start Date',
    'Start station number': 'StartStation Id',
    'Start station': 'StartStation Name',
    'End date': 'End Date',
    'End station number':'EndStation Id',
    'End station': 'EndStation Name',
    'Bike number': 'Bike Id',
    'Bike model': 'Bike Model',
    'Total duration (ms)': 'Duration'
}, inplace=True)
tmp2['Duration'] = (tmp2['Duration']/60).astype('int64')
tmp2['StartStation Id'] = tmp2['StartStation Id'].replace('300006-1', '300006').fillna(999999).astype('int64')
tmp2['EndStation Id'] = tmp2['EndStation Id'].replace('300006-1', '300006').fillna(999999).astype('int64')
tmp2['EndStation Name'] = tmp2['EndStation Name'].fillna('unknown')
tmp2['EndStation Name'] = tmp2['EndStation Name'].replace(" ,", ",")
tmp2['StartStation Name'] = tmp2['StartStation Name'].fillna('unknown')
tmp2['StartStation Name'] = tmp2['StartStation Name'].replace(" ,", ",")
tmp2['Bike Id'] = tmp2['Bike Id'].fillna(0)
tmp2['End Date'] = pd.to_datetime(tmp2['End Date'])
tmp2['Start Date'] = pd.to_datetime(tmp2['Start Date'])

# %%
tmp2[tmp2['StartStation Name'].str.contains('Coomer')]
# Out:
#         Rental Id          Start Date  StartStation Id  \
# 449     125423586 2022-09-25 22:26:00           300006
# 1677    125422330 2022-09-25 20:12:00           300006
# 2913    125421046 2022-09-25 18:58:00           300006
# 3315    125420630 2022-09-25 18:38:00           300006
# 3316    125420631 2022-09-25 18:38:00           300006
# ...           ...                 ...              ...
# 175850  125241110 2022-09-19 14:07:00           300006
# 179629  125237180 2022-09-19 12:02:00           300006
# 181369  125235421 2022-09-19 10:37:00           300006
# 181477  125235311 2022-09-19 10:31:00           300006
# 182709  125234008 2022-09-19 09:32:00           300006
#
#                         StartStation Name            End Date  EndStation Id  \
# 449     Coomer Place, West Kensington_OLD 2022-09-25 22:34:00           3459
# 1677    Coomer Place, West Kensington_OLD 2022-09-25 20:22:00           1172
# ...

# %%
pd.concat([tmp1,tmp2])
# Out:
#         Rental Id  Duration  Bike Id            End Date  EndStation Id  \
# 0        50754225       240    11834 2016-10-01 00:04:00            383
# 1        50754226       300     9648 2016-10-01 00:05:00            719
# 2        50754227      1200    10689 2016-10-01 00:20:00            272
# 3        50754228       780     8593 2016-10-01 00:14:00            471
# 4        50754229       600     8619 2016-10-01 00:11:00            399
# ...           ...       ...      ...                 ...            ...
# 186429  125230184     13844    57421 2022-09-19 00:14:00         200014
# 186430  125230185      9535    17815 2022-09-19 00:10:00           1194
# 186431  125230186      7234    51520 2022-09-19 00:08:00            988
# 186432  125230187     21993    51557 2022-09-19 00:22:00         300081
# 186433  125230188     30350    51804 2022-09-19 00:31:00           1193
#
#                             EndStation Name          Start Date  \
# ...

# %%
import os
for file in os.listdir('data'):
    print(os.path.join('data',file))
# Out:
# data/134JourneyDataExtract31Oct2018-06Nov2018.csv
# data/133JourneyDataExtract24Oct2018-30Oct2018.csv
# data/363JourneyDataExtract27Mar2023-02Apr2023.csv
# data/318JourneyDataExtract18May2022-24May2022.csv
# data/141JourneyDataExtract19Dec2018-25Dec2018.csv
# data/332JourneyDataExtract24Aug2022-30Aug2022.csv
# data/283JourneyDataExtract15Sep2021-21Sep2021.csv
# data/39JourneyDataExtract04Jan2017-10Jan2017.csv
# data/2a.JourneyDataExtract01Feb15-14Feb15.csv
# data/59JourneyDataExtract24May2017-30May2017.csv
# data/248JourneyDataExtract13Jan2021-19Jan2021.csv
# data/28JourneyDataExtract19Oct2016-25Oct2016.csv
# data/216JourneyDataExtract27May2020-02Jun2020.csv
# data/94JourneyDataExtract24Jan2018-30Jan2018.csv
# data/102JourneyDataExtract21Mar2018-27Mar2018.csv
# data/67JourneyDataExtract19Jul2017-25Jul2017.csv
# data/351JourneyDataExtract02Jan2023-08Jan2023.csv
# data/189JourneyDataExtract20Nov2019-26Nov2019.csv
# data/242JourneyDataExtract25Nov2020-01Dec2020.csv
# ...

# %%
df = pd.read_csv("data/341JourneyDataExtract24Oct2022-30Oct2022.csv")
# Out:
# /tmp/ipykernel_18475/1606330073.py:1: DtypeWarning: Columns (2,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("data/341JourneyDataExtract24Oct2022-30Oct2022.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202605 entries, 0 to 202604
# Data columns (total 11 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Number                202605 non-null  int64
#  1   Start date            202605 non-null  object
#  2   Start station number  202605 non-null  object
#  3   Start station         202605 non-null  object
#  4   End date              202605 non-null  object
#  5   End station number    202605 non-null  object
#  6   End station           202605 non-null  object
#  7   Bike number           202605 non-null  int64
#  8   Bike model            202605 non-null  object
#  9   Total duration        202605 non-null  object
#  10  Total duration (ms)   202605 non-null  int64
# dtypes: int64(3), object(8)
# memory usage: 17.0+ MB

# %%
for i, each in enumerate(df['Start station number'][:]):
    if each == '001085':
        print(each)
# Out:
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# 001085
# ...

# %%
df['Start station number'] = df['Start station number'].replace('300006-1', '300006') \
        .replace('200217old2', '200217').replace('001057_old', '001057') \
            .fillna(999999).astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202605 entries, 0 to 202604
# Data columns (total 11 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Number                202605 non-null  int64
#  1   Start date            202605 non-null  object
#  2   Start station number  202605 non-null  int64
#  3   Start station         202605 non-null  object
#  4   End date              202605 non-null  object
#  5   End station number    202605 non-null  object
#  6   End station           202605 non-null  object
#  7   Bike number           202605 non-null  int64
#  8   Bike model            202605 non-null  object
#  9   Total duration        202605 non-null  object
#  10  Total duration (ms)   202605 non-null  int64
# dtypes: int64(4), object(7)
# memory usage: 17.0+ MB

# %%
df.to_csv('test.csv', compression='gzip')

# %%
df.rename(columns={
        'Number': 'rental_id',
        'Start date':'start_date',
        'Start station number': 'startstation_id',
        'Start station': 'startstation_name',
        'End date': 'end_date',
        'End station number':'endstation_id',
        'End station': 'endstation_name',
        'Bike number': 'bike_id',
        'Bike model': 'bike_model',
        'Total duration (ms)': 'duration'
    }, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202605 entries, 0 to 202604
# Data columns (total 11 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   rental_id          202605 non-null  int64
#  1   start_date         202605 non-null  object
#  2   startstation_id    202605 non-null  int64
#  3   startstation_name  202605 non-null  object
#  4   end_date           202605 non-null  object
#  5   endstation_id      202605 non-null  object
#  6   endstation_name    202605 non-null  object
#  7   bike_id            202605 non-null  int64
#  8   bike_model         202605 non-null  object
#  9   Total duration     202605 non-null  object
#  10  duration           202605 non-null  int64
# dtypes: int64(4), object(7)
# memory usage: 17.0+ MB

# %%
def newstyle_cleaning(file_path):
    df = pd.read_csv(f'data/{file_path}')
    df.drop(columns='Total duration', inplace=True)
    df['Total duration (ms)'] = round(df['Total duration (ms)']/60)
    df['Start station number'] = df['Start station number'].replace('300006-1', '300006') \
        .replace('200217old2', '200217').replace('001057_old', '001057') \
            .fillna(999999).astype('int64')
    df['End station number'] = df['End station number'].replace('300006-1', '300006') \
        .replace('200217old2', '200217').replace('001057_old', '001057') \
            .fillna(999999).astype('int64')
    df['End station'] = df['End station'].fillna('unknown')
    df['End station'] = df['End station'].replace(" ,", ",")
    df['Start station'] = df['Start station'].fillna('unknown')
    df['Start station'] = df['Start station'].replace(" ,", ",")
    df['Bike number'] = df['Bike number'].fillna(0)
    df['End date'] = pd.to_datetime(df['End date'])
    df['Start date'] = pd.to_datetime(df['Start date'])
    df.rename(columns={
        'Number': 'rental_id',
        'Start date':'start_date',
        'Start station number': 'startstation_id',
        'Start station': 'startstation_name',
        'End date': 'end_date',
        'End station number':'endstation_id',
        'End station': 'endstation_name',
        'Bike number': 'bike_id',
        'Bike model': 'bike_model',
        'Total duration (ms)': 'duration'
    }, inplace=True)
    return df
df2 =newstyle_cleaning('341JourneyDataExtract24Oct2022-30Oct2022.csv')
# Out:
# /tmp/ipykernel_18475/663760684.py:2: DtypeWarning: Columns (2,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f'data/{file_path}')

# %%
df2.to_parquet('df2.parquet')
